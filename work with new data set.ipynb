# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# first i loaded the dataset
df = pd.read_csv('C:/Users/MSI KATANA/Desktop/DSGP Git Repo/DSGP-GROUP-9/newDataset.csv')
df
# Out:
#         Accident_Index Local_Authority_(District)       Date Day_of_Week  \
# 0        200501BS00001     Kensington and Chelsea   1/4/2005     Tuesday
# 1        200501BS00002     Kensington and Chelsea   1/5/2005   Wednesday
# 2        200501BS00003     Kensington and Chelsea   1/6/2005    Thursday
# 3        200501BS00004     Kensington and Chelsea   1/7/2005      Friday
# 4        200501BS00005     Kensington and Chelsea  1/10/2005      Monday
# ...                ...                        ...        ...         ...
# 1048570  201091NM01760                   Highland  2/18/2010    Thursday
# 1048571  201091NM01881                   Highland  2/21/2010      Sunday
# 1048572  201091NM01935                   Highland  2/23/2010     Tuesday
# 1048573  201091NM01964                   Highland  2/23/2010     Tuesday
# 1048574  201091NM02142                   Highland  2/28/2010      Sunday
#
#           Time  Year     Weather_Conditions Urban / Rural  Speed_limit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count    Dtype
# ---  ------                                   --------------    -----
#  0   Accident_Index                           1048575 non-null  object
#  1   Local_Authority_(District)               1048575 non-null  object
#  2   Date                                     1048575 non-null  object
#  3   Day_of_Week                              1048575 non-null  object
#  4   Time                                     1048475 non-null  object
#  5   Year                                     1048575 non-null  int64
#  6   Weather_Conditions                       1048575 non-null  object
#  7   Urban / Rural                            1048575 non-null  object
#  8   Speed_limit                              1048575 non-null  int64
#  9   Road_Type                                1048575 non-null  object
# ...

# %%
df.shape
# Out:
# (1048575, 17)

# %%
df['Pedestrian_Crossing-Physical_Facilities'].unique()
import math

# %%
filter1 = df['Pedestrian_Crossing-Physical_Facilities'].apply(lambda x : not (math.isnan(x)))

# %%
filter2 = df.loc[filter1]
filter2
# Out:
#         Accident_Index Local_Authority_(District)       Date Day_of_Week  \
# 0        200501BS00001     Kensington and Chelsea   1/4/2005     Tuesday
# 1        200501BS00002     Kensington and Chelsea   1/5/2005   Wednesday
# 2        200501BS00003     Kensington and Chelsea   1/6/2005    Thursday
# 3        200501BS00004     Kensington and Chelsea   1/7/2005      Friday
# 4        200501BS00005     Kensington and Chelsea  1/10/2005      Monday
# ...                ...                        ...        ...         ...
# 1048570  201091NM01760                   Highland  2/18/2010    Thursday
# 1048571  201091NM01881                   Highland  2/21/2010      Sunday
# 1048572  201091NM01935                   Highland  2/23/2010     Tuesday
# 1048573  201091NM01964                   Highland  2/23/2010     Tuesday
# 1048574  201091NM02142                   Highland  2/28/2010      Sunday
#
#           Time  Year     Weather_Conditions Urban / Rural  Speed_limit  \
# ...

# %%
filter2.shape
# Out:
# (1048538, 17)

# %%
df = filter2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1048538 entries, 0 to 1048574
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count    Dtype
# ---  ------                                   --------------    -----
#  0   Accident_Index                           1048538 non-null  object
#  1   Local_Authority_(District)               1048538 non-null  object
#  2   Date                                     1048538 non-null  object
#  3   Day_of_Week                              1048538 non-null  object
#  4   Time                                     1048439 non-null  object
#  5   Year                                     1048538 non-null  int64
#  6   Weather_Conditions                       1048538 non-null  object
#  7   Urban / Rural                            1048538 non-null  object
#  8   Speed_limit                              1048538 non-null  int64
#  9   Road_Type                                1048538 non-null  object
# ...

# %%
df
# Out:
#         Accident_Index Local_Authority_(District)       Date Day_of_Week  \
# 0        200501BS00001     Kensington and Chelsea   1/4/2005     Tuesday
# 1        200501BS00002     Kensington and Chelsea   1/5/2005   Wednesday
# 2        200501BS00003     Kensington and Chelsea   1/6/2005    Thursday
# 3        200501BS00004     Kensington and Chelsea   1/7/2005      Friday
# 4        200501BS00005     Kensington and Chelsea  1/10/2005      Monday
# ...                ...                        ...        ...         ...
# 1048570  201091NM01760                   Highland  2/18/2010    Thursday
# 1048571  201091NM01881                   Highland  2/21/2010      Sunday
# 1048572  201091NM01935                   Highland  2/23/2010     Tuesday
# 1048573  201091NM01964                   Highland  2/23/2010     Tuesday
# 1048574  201091NM02142                   Highland  2/28/2010      Sunday
#
#           Time  Year     Weather_Conditions Urban / Rural  Speed_limit  \
# ...

# %%
df.to_csv("edit1Newdataset.csv")

# %%
df['Day_of_Week'].value_counts()
# Out:
# Day_of_Week
# Friday       171905
# Wednesday    157982
# Tuesday      156116
# Thursday     155783
# Monday       148499
# Saturday     142223
# Sunday       116030
# Name: count, dtype: int64

# %%
# first i loaded the dataset
df1 = pd.read_csv('C:/Users/MSI KATANA/Desktop/DSGP Git Repo/DSGP-GROUP-9/edit1Newdataset.csv')
df1
# Out:
#          Unnamed: 0 Accident_Index Local_Authority_(District)       Date  \
# 0                 0  200501BS00001     Kensington and Chelsea   1/4/2005
# 1                 1  200501BS00002     Kensington and Chelsea   1/5/2005
# 2                 2  200501BS00003     Kensington and Chelsea   1/6/2005
# 3                 3  200501BS00004     Kensington and Chelsea   1/7/2005
# 4                 4  200501BS00005     Kensington and Chelsea  1/10/2005
# ...             ...            ...                        ...        ...
# 1048533     1048570  201091NM01760                   Highland  2/18/2010
# 1048534     1048571  201091NM01881                   Highland  2/21/2010
# 1048535     1048572  201091NM01935                   Highland  2/23/2010
# 1048536     1048573  201091NM01964                   Highland  2/23/2010
# 1048537     1048574  201091NM02142                   Highland  2/28/2010
#
#         Day_of_Week   Time  Year     Weather_Conditions Urban / Rural  \
# ...

# %%
# main selected fields
selected_columns = ['Accident_Index', 'Date', 'Day_of_Week', 'Time', 'Local_Authority_(District)'] 
df_selected = df1[selected_columns]
df_selected
# Out:
#         Accident_Index       Date Day_of_Week   Time  \
# 0        200501BS00001   1/4/2005     Tuesday  17:42
# 1        200501BS00002   1/5/2005   Wednesday  17:36
# 2        200501BS00003   1/6/2005    Thursday   0:15
# 3        200501BS00004   1/7/2005      Friday  10:35
# 4        200501BS00005  1/10/2005      Monday  21:13
# ...                ...        ...         ...    ...
# 1048533  201091NM01760  2/18/2010    Thursday   7:00
# 1048534  201091NM01881  2/21/2010      Sunday   3:00
# 1048535  201091NM01935  2/23/2010     Tuesday   9:38
# 1048536  201091NM01964  2/23/2010     Tuesday  18:25
# 1048537  201091NM02142  2/28/2010      Sunday  15:45
#
#         Local_Authority_(District)
# 0           Kensington and Chelsea
# 1           Kensington and Chelsea
# 2           Kensington and Chelsea
# 3           Kensington and Chelsea
# 4           Kensington and Chelsea
# ...                            ...
# 1048533                   Highland
# 1048534                   Highland
# ...

# %%
# Checking  missing values in the DataFrame
missing_values_in_data_frame = df_selected.isnull()

# number of missing values in each column
missing_values_count_in_data_frame = df_selected.isnull().sum()

# print the result
print("Missing Values in Each Column:")
print(missing_values_count_in_data_frame)
# Out:
# Missing Values in Each Column:
# Accident_Index                 0
# Date                           0
# Day_of_Week                    0
# Time                          99
# Local_Authority_(District)     0
# dtype: int64

# %%
# drop the rows with any missing values
df_selected = df_selected.dropna()
df_selected
# Out:
#         Accident_Index       Date Day_of_Week   Time  \
# 0        200501BS00001   1/4/2005     Tuesday  17:42
# 1        200501BS00002   1/5/2005   Wednesday  17:36
# 2        200501BS00003   1/6/2005    Thursday   0:15
# 3        200501BS00004   1/7/2005      Friday  10:35
# 4        200501BS00005  1/10/2005      Monday  21:13
# ...                ...        ...         ...    ...
# 1048533  201091NM01760  2/18/2010    Thursday   7:00
# 1048534  201091NM01881  2/21/2010      Sunday   3:00
# 1048535  201091NM01935  2/23/2010     Tuesday   9:38
# 1048536  201091NM01964  2/23/2010     Tuesday  18:25
# 1048537  201091NM02142  2/28/2010      Sunday  15:45
#
#         Local_Authority_(District)
# 0           Kensington and Chelsea
# 1           Kensington and Chelsea
# 2           Kensington and Chelsea
# 3           Kensington and Chelsea
# 4           Kensington and Chelsea
# ...                            ...
# 1048533                   Highland
# 1048534                   Highland
# ...

# %%
# remove the duplicate values in rows 
df_selected = df_selected.drop_duplicates()
df_selected
# Out:
#         Accident_Index       Date Day_of_Week   Time  \
# 0        200501BS00001   1/4/2005     Tuesday  17:42
# 1        200501BS00002   1/5/2005   Wednesday  17:36
# 2        200501BS00003   1/6/2005    Thursday   0:15
# 3        200501BS00004   1/7/2005      Friday  10:35
# 4        200501BS00005  1/10/2005      Monday  21:13
# ...                ...        ...         ...    ...
# 1048533  201091NM01760  2/18/2010    Thursday   7:00
# 1048534  201091NM01881  2/21/2010      Sunday   3:00
# 1048535  201091NM01935  2/23/2010     Tuesday   9:38
# 1048536  201091NM01964  2/23/2010     Tuesday  18:25
# 1048537  201091NM02142  2/28/2010      Sunday  15:45
#
#         Local_Authority_(District)
# 0           Kensington and Chelsea
# 1           Kensington and Chelsea
# 2           Kensington and Chelsea
# 3           Kensington and Chelsea
# 4           Kensington and Chelsea
# ...                            ...
# 1048533                   Highland
# 1048534                   Highland
# ...

# %%
# Checking  missing values in the DataFrame
missing_values_in_data_frame = df_selected.isnull()

# number of missing values in each column
missing_values_count_in_data_frame = df_selected.isnull().sum()

# print the result
print("Missing Values in Each Column:")
print(missing_values_count_in_data_frame)
# Out:
# Missing Values in Each Column:
# Accident_Index                0
# Date                          0
# Day_of_Week                   0
# Time                          0
# Local_Authority_(District)    0
# dtype: int64

# %%
# confirmd no missing values

# %%
# Assuming your original DataFrame is named 'df_selected'
# Specify the correct date format using the 'format' parameter and 'dayfirst=True'
df_selected['Year'] = pd.to_datetime(df_selected['Date'], format='%m/%d/%Y', dayfirst=True).dt.year

# Map day of the week numbers to day names
day_mapping = {1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday', 7: 'Sunday'}
df_selected['Day_of_the_Week'] = pd.to_datetime(df_selected['Date'], format='%m/%d/%Y', dayfirst=True).dt.dayofweek.map(day_mapping)

# Create a new column for time periods (1 to 24)
df_selected['Time_Period'] = pd.to_datetime(df_selected['Time']).dt.hour + 1

# Create a new DataFrame with the desired format
result_df = df_selected.groupby(['Local_Authority_(District)', 'Year', 'Day_of_the_Week', 'Time_Period'])['Accident_Index'].count().reset_index()
result_df.rename(columns={'Accident_Index': 'Acc. Count'}, inplace=True)

# Print the first few rows of the result DataFrame
print(result_df.head(1000))
# Out:
# C:\Users\MSI KATANA\AppData\Local\Temp\ipykernel_11968\133000641.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Year'] = pd.to_datetime(df_selected['Date'], format='%m/%d/%Y', dayfirst=True).dt.year
# C:\Users\MSI KATANA\AppData\Local\Temp\ipykernel_11968\133000641.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Day_of_the_Week'] = pd.to_datetime(df_selected['Date'], format='%m/%d/%Y', dayfirst=True).dt.dayofweek.map(day_mapping)
# ...

# %%
result_df
# Out:
#        Local_Authority_(District)  Year Day_of_the_Week  Time_Period  \
# 0                   Aberdeen City  2005          Friday            1
# 1                   Aberdeen City  2005          Friday            2
# 2                   Aberdeen City  2005          Friday            3
# 3                   Aberdeen City  2005          Friday            4
# 4                   Aberdeen City  2005          Friday            5
# ...                           ...   ...             ...          ...
# 249426                       York  2010       Wednesday           19
# 249427                       York  2010       Wednesday           20
# 249428                       York  2010       Wednesday           21
# 249429                       York  2010       Wednesday           22
# 249430                       York  2010       Wednesday           24
#
#         Acc. Count
# 0                5
# 1                2
# 2                1
# 3                2
# 4                1
# ...

# %%
result_df.describe()
# Out:
#                 Year    Time_Period     Acc. Count
# count  249431.000000  249431.000000  249431.000000
# mean     2007.398166      13.879153       3.603165
# std         1.683902       6.225774       3.453796
# min      2005.000000       1.000000       1.000000
# 25%      2006.000000       9.000000       1.000000
# 50%      2007.000000      14.000000       3.000000
# 75%      2009.000000      19.000000       5.000000
# max      2010.000000      24.000000      72.000000

# %%
# Assuming your DataFrame is named 'df_stats'
variance_year = result_df['Year'].var()
variance_time_period = result_df['Time_Period'].var()
variance_acc_count = result_df['Acc. Count'].var()

print(f'Variance for Year: {variance_year}')
print(f'Variance for Time_Period: {variance_time_period}')
print(f'Variance for Acc. Count: {variance_acc_count}')
# Out:
# Variance for Year: 2.8355254830304717
# Variance for Time_Period: 38.76026262853202
# Variance for Acc. Count: 11.9287056958318

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249431 entries, 0 to 249430
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Local_Authority_(District)  249431 non-null  object
#  1   Year                        249431 non-null  int32
#  2   Day_of_the_Week             249431 non-null  object
#  3   Time_Period                 249431 non-null  int32
#  4   Acc. Count                  249431 non-null  int64
# dtypes: int32(2), int64(1), object(2)
# memory usage: 7.6+ MB

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno

# %%
# Plot a matrix of missing values
msno.matrix(result_df)
plt.show()

# Plot a bar chart showing the percentage of missing values in each column
msno.bar(result_df)
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(result_df.isnull(), cbar=False, cmap='viridis')
plt.show()


# here if there are any missing value we can see it in yellow color

# %%
# we can confirm now no missing values in the data set

# %%
plt.figure(figsize=(12, 70))  # Increase the figure size
ax = sns.countplot(y='Local_Authority_(District)', data=df, palette='viridis', order=df['Local_Authority_(District)'].value_counts().index)
plt.title('Distribution of Accidents by District')

# Annotate each bar with its count
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width() + 0.1, p.get_y() + p.get_height() / 2), ha='left', va='center')

plt.tight_layout()  # Adjust spacing
plt.show()

# %%
# Bar plot for 'Year'
plt.figure(figsize=(10, 6))
sns.countplot(x='Year', data=df, palette='viridis')
plt.title('Distribution of Accidents by Year')
plt.show()

# %%
# Bar plot for 'Day_of_the_Week'
plt.figure(figsize=(8, 6))
ax = sns.countplot(x='Day_of_Week', data=df, palette='viridis', order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.title('Distribution of Accidents by Day of the Week')

# Annotate each bar with its count
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height() + 0.1), ha='center', va='bottom')

plt.show()

# %%
# Check the current data type of 'Date' column
print(df['Date'].dtype)

# If it's not datetime, convert it
df['Date'] = pd.to_datetime(df['Date'])

# Check the data type again
print(df['Date'].dtype)

# Reset the index before creating the time series plot
df_reset_index = df.groupby('Date').size().reset_index(name='Accident Count')

# Create a time series plot
plt.figure(figsize=(14, 6))
sns.lineplot(x='Date', y='Accident Count', data=df_reset_index, color='black')

plt.title('Accidents Over Time')
plt.xlabel('Date')
plt.ylabel('Accident Count')
plt.show()
# Out:
# datetime64[ns]
# datetime64[ns]
# C:\Users\MSI KATANA\AppData\Local\Temp\ipykernel_11968\1826078103.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
# Convert 'Time_Period' to string type
result_df['Time_Period'] = result_df['Time_Period'].astype(str)

# Extract the numerical part of 'Time_Period'
result_df['Time_Period_Num'] = result_df['Time_Period'].str.extract('(\d+)').astype(int)

# Sort DataFrame by 'Time_Period_Num' for proper line plotting
result_df_sorted = result_df.sort_values(by='Time_Period_Num')

# Create a line plot for aggregated 'Acc. Count' over different time periods
plt.figure(figsize=(14, 6))
sns.lineplot(x='Time_Period', y='Acc. Count', data=result_df_sorted, marker='o')

plt.title('Accident Count Over Different Time Periods')
plt.xlabel('Time Period')
plt.ylabel('Accident Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Select numerical columns for correlation analysis
numerical_columns = result_df.select_dtypes(include=['float64', 'int64']).columns

# Compute the correlation matrix
correlation_matrix = result_df[numerical_columns].corr()

# Create a heatmap for visualization
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %%
pip install scipy
# Out:
# ...
#
# ...

# %%
import scipy

# %%
from scipy import stats  

# Box plot to visualize outliers
plt.figure(figsize=(12, 6))
sns.boxplot(x='Acc. Count', data=result_df)
plt.title('Box Plot of Acc. Count')
plt.show()

# Calculate z-scores for 'Acc. Count'
z_scores = stats.zscore(result_df['Acc. Count'])

# Define a threshold for z-scores, e.g., 3
threshold = 3

# Identify and remove outliers
result_df_no_outliers = result_df[(z_scores < threshold) & (z_scores > -threshold)]

# Display the DataFrame without outliers
print(result_df_no_outliers.head())
# Out:
#   Local_Authority_(District)  Year Day_of_the_Week Time_Period  Acc. Count  \
# 0              Aberdeen City  2005          Friday           1           5
# 1              Aberdeen City  2005          Friday           2           2
# 2              Aberdeen City  2005          Friday           3           1
# 3              Aberdeen City  2005          Friday           4           2
# 4              Aberdeen City  2005          Friday           5           1
#
#    Time_Period_Num
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
