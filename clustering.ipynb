# %%
import pandas as pd
from sklearn.cluster import DBSCAN
import numpy as np

df = pd.read_csv("cleaned_dataset.csv")
print(df)

# Selecting only the spatial coordinates for clustering
coordinates = df[['Latitude', 'Longitude']]
# Out:
#         Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0        200501BS00001               525680.0                178240.0
# 1        200501BS00002               524170.0                181650.0
# 2        200501BS00003               524520.0                182240.0
# 3        200501BS00004               526900.0                177530.0
# 4        200501BS00005               528060.0                179040.0
# ...                ...                    ...                     ...
# 1041497  201201LX50301               530140.0                170990.0
# 1041498  201201LX50302               529820.0                170510.0
# 1041499  201201LX50303               530650.0                176730.0
# 1041500  201201LX50304               532220.0                172500.0
# 1041501  201201LX50305               531180.0                177000.0
#
#          Longitude   Latitude Local_Authority_(District)  \
# 0        -0.191170  51.489096     Kensington and Chelsea
# 1        -0.211708  51.520075     Kensington and Chelsea
# 2        -0.206458  51.525301     Kensington and Chelsea
# 3        -0.173862  51.482442     Kensington and Chelsea
# 4        -0.156618  51.495752     Kensington and Chelsea
# ...            ...        ...                        ...
# 1041497  -0.129632  51.422932                   Highland
# 1041498  -0.134408  51.418692                   Highland
# 1041499  -0.120183  51.474400                   Highland
# 1041500  -0.099170  51.436021                   Highland
# 1041501  -0.112456  51.476704                   Highland
#
#             Weather_Conditions  Number_of_Vehicles  \
# 0        Raining no high winds                 1.0
# 1           Fine no high winds                 1.0
# 2           Fine no high winds                 2.0
# 3           Fine no high winds                 1.0
# 4           Fine no high winds                 1.0
# ...                        ...                 ...
# 1041497     Fine no high winds                 1.0
# 1041498     Fine no high winds                 1.0
# 1041499     Fine no high winds                 3.0
# 1041500     Fine no high winds                 2.0
# 1041501  Snowing no high winds                 1.0
#
#                              Junction_Detail
# 0        Not at junction or within 20 metres
# 1                                 Crossroads
# 2        Not at junction or within 20 metres
# 3        Not at junction or within 20 metres
# 4        Not at junction or within 20 metres
# ...                                      ...
# 1041497  Not at junction or within 20 metres
# 1041498  Not at junction or within 20 metres
# 1041499              T or staggered junction
# 1041500              T or staggered junction
# 1041501              T or staggered junction
#
# [1041502 rows x 9 columns]

# %%
# DBSCAN Clustering
# eps: The maximum distance between two samples for one to be considered as in the neighborhood of the other
# min_samples: The number of samples in a neighborhood for a point to be considered as a core point

dbscan = DBSCAN(eps=0.01, min_samples=10)  # these parameters need to be tuned
clusters = dbscan.fit_predict(coordinates)

# Adding the cluster labels to your dataset
df['Cluster'] = clusters

# %%
# Count the number of accidents in each cluster
cluster_counts = df['Cluster'].value_counts()
threshold = 50

# Identify potential hotspots (clusters with high counts)
hotspots = cluster_counts[cluster_counts > threshold]  # define an appropriate threshold

print(hotspots)
# Out:
# Cluster
#  0       601442
# -1        64380
#  147      30489
#  2279     22601
#  1299     18888
#           ...
#  1089        51
#  1266        51
#  541         51
#  1882        51
#  1290        51
# Name: count, Length: 512, dtype: int64

# %%
import folium

sample_data = df.sample(n=1000)  # Adjust n to your needs
# Then use sample_data instead of new_dataset for plotting


# Create a map centered around an average location
map_center = [sample_data['Latitude'].mean(), sample_data['Longitude'].mean()]
map = folium.Map(location=map_center, zoom_start=12)

# Add each accident point to the map
for _, row in sample_data.iterrows():
    cluster = row['Cluster']
    if cluster != -1:  # -1 is for noise points
        folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                            radius=3,
                            color='blue' if cluster == 0 else 'red',  # Change colors if you have more clusters
                            fill=True,
                            fill_color='blue' if cluster == 0 else 'red',
                            fill_opacity=0.6).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0e1b9f17d5096be2f68f93a0866fab9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0e1b9f17d5096be2f68f93a0866fab9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0e1b9f17d5096be2f68f93a0866fab9 = L.map(
#                 &quot;map_a0e1b9f17d5096be2f68f93a0866fab9&quot;,
#                 {
#                     center: [52.677324257, -1.4858006639999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd73286160d582d3750855d8f0b8c0a1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_fd73286160d582d3750855d8f0b8c0a1.addTo(map_a0e1b9f17d5096be2f68f93a0866fab9);
#
#             var circle_marker_b51833f1340a248a3fffb317a583c123 = L.circleMarker(
#                 [52.912313, -1.514589],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a0e1b9f17d5096be2f68f93a0866fab9);
#
#
#             var circle_marker_47dca00810b75a7a697efe67dd0b0e4c = L.circleMarker(
#                 [51.765555, -0.478969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a0e1b9f17d5096be2f68f93a0866fab9);
#
#
#             var circle_marker_23a73e300584ae3c3539b62270d21064 = L.circleMarker(
#                 [52.093616, 0.295831],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a0e1b9f17d5096be2f68f93a0866fab9);
#
#
#             var circle_marker_f1a9cf9dcc4f4233e44df8f47a0850dd = L.circleMarker(
#                 [52.948342, -1.448403],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a0e1b9f17d5096be2f68f93a0866fab9);
#
#
#             var circle_marker_4ed5269fd3a08681679fdd1c68214b23 = L.circleMarker(
#                 [53.490233, -2.323411],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a0e1b9f17d5096be2f68f93a0866fab9);
#
#
#             var circle_marker_0f354d80001b39ac2ae43e6ef6beacee = L.circleMarker(
#                 [52.268506, -0.85809],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a0e1b9f17d5096be2f68f93a0866fab9);
#
#
#             var circle_marker_50

# %%
import pandas as pd
#Data preperation.

# Group by Local_Authority_(District) and count the accidents
district_counts = df.groupby('Local_Authority_(District)').agg({'Latitude': 'mean', 'Longitude': 'mean', 'Accident_Index': 'count'}).reset_index()
district_counts.rename(columns={'Accident_Index': 'Accident_Count'}, inplace=True)

# %%
import folium

average_latitude = df['Latitude'].mean()
average_longitude = df['Longitude'].mean()


# Create a base map
map = folium.Map(location=[average_latitude, average_longitude], zoom_start=6)

# Add markers to the map
for _, row in district_counts.iterrows():
    location = [row['Latitude'], row['Longitude']]
    tooltip = f"{row['Local_Authority_(District)']}: {row['Accident_Count']} accidents"
    
    folium.Marker(
        location=location,
        popup=tooltip,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_325210dccda069ef7929193c9a2375ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_325210dccda069ef7929193c9a2375ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_325210dccda069ef7929193c9a2375ec = L.map(
#                 &quot;map_325210dccda069ef7929193c9a2375ec&quot;,
#                 {
#                     center: [52.58413878328415, -1.450722221756656],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf1b5924faf6e4a4c5329befa587a42c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_bf1b5924faf6e4a4c5329befa587a42c.addTo(map_325210dccda069ef7929193c9a2375ec);
#
#             var marker_2f934386235e11491e8f51231d96fc1a = L.marker(
#                 [55.64748498425572, -2.2091495982824427],
#                 {}
#             ).addTo(map_325210dccda069ef7929193c9a2375ec);
#
#
#             var icon_8129818d054de03bf7c78555bfcb19bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2f934386235e11491e8f51231d96fc1a.setIcon(icon_8129818d054de03bf7c78555bfcb19bc);
#
#
#         var popup_8d737634aa7ecd0015c08c261a088fe9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_90cc11d43d1573189f570c3a72cd981c = $(`&lt;div id=&quot;html_90cc11d43d1573189f570c3a72cd981c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aberdeen City: 2096 accidents&lt;/div&gt;`)[0];
#                 popup_8d737634aa7ecd0015c08c261a088fe9.setContent(html_90cc11d43d1573189f570c3a72cd981c);
#
#
#
#         marker_2f934386235e11491e8f51231d96fc1a.bindPopup(popup_8d737634aa7ecd0015c08c261a088fe9)
#         ;
#
#
#
#
#             var marker_956105cf4d1bdb7bba6bf0d64adf0c10 = L.marker(
#                 [55.67188070019854, -2.238294620119126],
#                 {}
#             ).addTo(map_325210dccda069ef7929193c9a2375ec);
#
#
#             var icon_3f7b41781c9923a79184be19242db82e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_956105cf4d1bdb7bba6bf0d64adf0c10.setIcon(icon_3f7b41781c9923a79184be19242db82e);
#
#
#         var popup_8713b300ad2b0e4c636bf125b8947c63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f85f8e86489ced892d39e7f06ad09112 = $(`&lt;div id=&quot;html_f85f8e86489ced892d39e7f06ad09112&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aberdeenshire: 3022 accidents&lt;/div&gt;`)[0];
#                 popup_8713b300ad2b0e4c636bf125b8947c63.setContent(html_f85f8e86489ced892d39e7f06ad09112);
#
#
#
#         marker_956105cf4d1bdb7bba6bf0d64adf0c10.bindPopup(popup_8713b300ad2b0e4c636bf125b8947c63)
#         ;
#
#
#
#
#             var marker_15d482613b14c13914deb718687b0fe6 = L.marker(
#                 [51.045162896367515, -1.7190630844017092],
#                 {}
#             ).addTo(map_325210dccda069ef7929193c9a2375ec);
#
#
#             var icon_1fcf472b30069c8811f9e60a8da46cf1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_15d482613b14c13914deb718687b0fe6.setIcon(icon_1fcf472b30069c8811f9e60a8da46cf1);
#
#
#         var popup_8fa964b34b78be63724495cbc60a40c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb1566ff7111e97281d73d314b155dc0 = $(`&lt;div id=&quot;html_fb1566ff7111e97281d73d314b155dc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adur: 936 accidents&lt;/div&gt;`)[0];
#                 popup_8fa964b34b78be63724495cbc60a40c8.setContent(html_fb1566ff7111e97281d73d314b155dc0);
#
#
#
#         marker_15d482613b14c13914deb718687b0fe6.bindPopup(popup_8fa964b34b78be63724495cbc60a40c8)
#         ;
#
#
#
#
#             var marker_53c88c7d44748783df01c022105e7ccf = L.marker(
#                 [54.36469104786036, -3.0238296300675676],
#                 {}
#             ).addTo(map_325210dccda069ef7929193c9a2375e

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
import folium

sample_data = df.sample(n=1000)

# Filter data for a specific weather condition
weather_df = sample_data[sample_data['Weather_Conditions'] == 'Fine no high winds']

#Perform DBSCAN clusterng
dbscan = DBSCAN(eps=0.01, min_samples=10).fit(weather_df[['Latitude', 'Longitude']])
weather_df['Cluster'] = dbscan.labels_

# Filter out noise points
clustered_df = weather_df[weather_df['Cluster'] != -1]

# Create a Folium map
map = folium.Map(location=[sample_data['Latitude'].mean(), sample_data['Longitude'].mean()], zoom_start=12)

# Add clusters to the map
for cluster_num in set(clustered_df['Cluster']):
    cluster_data = clustered_df[clustered_df['Cluster'] == cluster_num]
    for _, row in cluster_data.iterrows():
        folium.CircleMarker(location=[row['Latitude'], row['Longitude']], 
                            radius=5, 
                            color='red', 
                            fill=True).add_to(map)
map
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1332\4197074089.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather_df['Cluster'] = dbscan.labels_
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a1b6c3d6e12eaf2bba6a523c80e575c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a1b6c3d6e12eaf2bba6a523c80e575c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a1b6c3d6e12eaf2bba6a523c80e575c = L.map(
#                 &quot;map_5a1b6c3d6e12eaf2bba6a523c80e575c&quot;,
#                 {
#                     center: [52.627384963000004, -1.422011631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55a5db861e7dd8f43f8740caa0ebb9da = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_55a5db861e7dd8f43f8740caa0ebb9da.addTo(map_5a1b6c3d6e12eaf2bba6a523c80e575c);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
