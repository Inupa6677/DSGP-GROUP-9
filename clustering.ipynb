# %%
import pandas as pd
from sklearn.cluster import DBSCAN
import numpy as np

df = pd.read_csv("cleaned_dataset.csv")
print(df)

# Selecting only the spatial coordinates for clustering
coordinates = df[['Latitude', 'Longitude']]
# Out:
#         Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0        200501BS00001               525680.0                178240.0
# 1        200501BS00002               524170.0                181650.0
# 2        200501BS00003               524520.0                182240.0
# 3        200501BS00004               526900.0                177530.0
# 4        200501BS00005               528060.0                179040.0
# ...                ...                    ...                     ...
# 1041497  201201LX50301               530140.0                170990.0
# 1041498  201201LX50302               529820.0                170510.0
# 1041499  201201LX50303               530650.0                176730.0
# 1041500  201201LX50304               532220.0                172500.0
# 1041501  201201LX50305               531180.0                177000.0
#
#          Longitude   Latitude Local_Authority_(District)  \
# 0        -0.191170  51.489096     Kensington and Chelsea
# 1        -0.211708  51.520075     Kensington and Chelsea
# 2        -0.206458  51.525301     Kensington and Chelsea
# 3        -0.173862  51.482442     Kensington and Chelsea
# 4        -0.156618  51.495752     Kensington and Chelsea
# ...            ...        ...                        ...
# 1041497  -0.129632  51.422932                   Highland
# 1041498  -0.134408  51.418692                   Highland
# 1041499  -0.120183  51.474400                   Highland
# 1041500  -0.099170  51.436021                   Highland
# 1041501  -0.112456  51.476704                   Highland
#
#             Weather_Conditions  Number_of_Vehicles  \
# 0        Raining no high winds                 1.0
# 1           Fine no high winds                 1.0
# 2           Fine no high winds                 2.0
# 3           Fine no high winds                 1.0
# 4           Fine no high winds                 1.0
# ...                        ...                 ...
# 1041497     Fine no high winds                 1.0
# 1041498     Fine no high winds                 1.0
# 1041499     Fine no high winds                 3.0
# 1041500     Fine no high winds                 2.0
# 1041501  Snowing no high winds                 1.0
#
#                              Junction_Detail
# 0        Not at junction or within 20 metres
# 1                                 Crossroads
# 2        Not at junction or within 20 metres
# 3        Not at junction or within 20 metres
# 4        Not at junction or within 20 metres
# ...                                      ...
# 1041497  Not at junction or within 20 metres
# 1041498  Not at junction or within 20 metres
# 1041499              T or staggered junction
# 1041500              T or staggered junction
# 1041501              T or staggered junction
#
# [1041502 rows x 9 columns]

# %%
# DBSCAN Clustering
# eps: The maximum distance between two samples for one to be considered as in the neighborhood of the other
# min_samples: The number of samples in a neighborhood for a point to be considered as a core point

dbscan = DBSCAN(eps=0.01, min_samples=10)  # these parameters need to be tuned
clusters = dbscan.fit_predict(coordinates)

# Adding the cluster labels to your dataset
df['Cluster'] = clusters

# %%
# Count the number of accidents in each cluster
cluster_counts = df['Cluster'].value_counts()
threshold = 50

# Identify potential hotspots (clusters with high counts)
hotspots = cluster_counts[cluster_counts > threshold]  # define an appropriate threshold

print(hotspots)
# Out:
# Cluster
#  0       601442
# -1        64380
#  147      30489
#  2279     22601
#  1299     18888
#           ...
#  1089        51
#  1266        51
#  541         51
#  1882        51
#  1290        51
# Name: count, Length: 512, dtype: int64

# %%
import folium

sample_data = df.sample(n=1000)  # Adjust n to your needs
# Then use sample_data instead of new_dataset for plotting


# Create a map centered around an average location
map_center = [sample_data['Latitude'].mean(), sample_data['Longitude'].mean()]
map = folium.Map(location=map_center, zoom_start=12)

# Add each accident point to the map
for _, row in sample_data.iterrows():
    cluster = row['Cluster']
    if cluster != -1:  # -1 is for noise points
        folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                            radius=3,
                            color='blue' if cluster == 0 else 'red',  # Change colors if you have more clusters
                            fill=True,
                            fill_color='blue' if cluster == 0 else 'red',
                            fill_opacity=0.6).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c223b6f1a3b6bf90d3624114f7adde9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c223b6f1a3b6bf90d3624114f7adde9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c223b6f1a3b6bf90d3624114f7adde9 = L.map(
#                 &quot;map_4c223b6f1a3b6bf90d3624114f7adde9&quot;,
#                 {
#                     center: [52.515945265, -1.544383918],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2818cd6fb1c72bf1ab54b7bebe258d6c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_2818cd6fb1c72bf1ab54b7bebe258d6c.addTo(map_4c223b6f1a3b6bf90d3624114f7adde9);
#
#             var circle_marker_9840b48390bf5c11ce55b84af52db7d0 = L.circleMarker(
#                 [52.694315, -1.088054],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4c223b6f1a3b6bf90d3624114f7adde9);
#
#
#             var circle_marker_9955949265bf31a444d3189a90ffb3f4 = L.circleMarker(
#                 [52.223944, -2.209899],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4c223b6f1a3b6bf90d3624114f7adde9);
#
#
#             var circle_marker_6a5de60c78d62f84a604dfca5d80d279 = L.circleMarker(
#                 [50.875141, 0.011816],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4c223b6f1a3b6bf90d3624114f7adde9);
#
#
#             var circle_marker_1b853f1820e4007b9ab24f2c3e5a0313 = L.circleMarker(
#                 [51.404345, -3.203147],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4c223b6f1a3b6bf90d3624114f7adde9);
#
#
#             var circle_marker_193e1ebf6819130130c9b9aab1917ca3 = L.circleMarker(
#                 [54.568793, -1.23944],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4c223b6f1a3b6bf90d3624114f7adde9);
#
#
#             var circle_marker_e8458b6d2bf800c3ef9c5793bb0e6168 = L.circleMarker(
#                 [52.28376, -2.125744],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4c223b6f1a3b6bf90d3624114f7adde9);
#
#
#             var circle_marker_5ac8b1741e8c

# %%
import pandas as pd
#Data preperation.

# Group by Local_Authority_(District) and count the accidents
district_counts = df.groupby('Local_Authority_(District)').agg({'Latitude': 'mean', 'Longitude': 'mean', 'Accident_Index': 'count'}).reset_index()
district_counts.rename(columns={'Accident_Index': 'Accident_Count'}, inplace=True)

# %%
import folium

average_latitude = df['Latitude'].mean()
average_longitude = df['Longitude'].mean()


# Create a base map
map = folium.Map(location=[average_latitude, average_longitude], zoom_start=6)

# Add markers to the map
for _, row in district_counts.iterrows():
    location = [row['Latitude'], row['Longitude']]
    tooltip = f"{row['Local_Authority_(District)']}: {row['Accident_Count']} accidents"
    
    folium.Marker(
        location=location,
        popup=tooltip,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f55c1fa3c507a58fbd6798caa5a1931a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f55c1fa3c507a58fbd6798caa5a1931a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f55c1fa3c507a58fbd6798caa5a1931a = L.map(
#                 &quot;map_f55c1fa3c507a58fbd6798caa5a1931a&quot;,
#                 {
#                     center: [52.58413878328415, -1.450722221756656],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a117291e6f5a52650e19c6168dd64b6f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_a117291e6f5a52650e19c6168dd64b6f.addTo(map_f55c1fa3c507a58fbd6798caa5a1931a);
#
#             var marker_fdf352362378b0d76384cd443af38a77 = L.marker(
#                 [55.64748498425572, -2.2091495982824427],
#                 {}
#             ).addTo(map_f55c1fa3c507a58fbd6798caa5a1931a);
#
#
#             var icon_1fb91d3122cd945bec004e4b8c1267c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fdf352362378b0d76384cd443af38a77.setIcon(icon_1fb91d3122cd945bec004e4b8c1267c6);
#
#
#         var popup_f8f2cd5a4b160cbe7fd769907fcb6930 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_877eab37267b832709b1afefcedac33a = $(`&lt;div id=&quot;html_877eab37267b832709b1afefcedac33a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aberdeen City: 2096 accidents&lt;/div&gt;`)[0];
#                 popup_f8f2cd5a4b160cbe7fd769907fcb6930.setContent(html_877eab37267b832709b1afefcedac33a);
#
#
#
#         marker_fdf352362378b0d76384cd443af38a77.bindPopup(popup_f8f2cd5a4b160cbe7fd769907fcb6930)
#         ;
#
#
#
#
#             var marker_2159def539d47a234707497674b21748 = L.marker(
#                 [55.67188070019854, -2.238294620119126],
#                 {}
#             ).addTo(map_f55c1fa3c507a58fbd6798caa5a1931a);
#
#
#             var icon_5db38c6c4f3661d83ad1009b1729446d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2159def539d47a234707497674b21748.setIcon(icon_5db38c6c4f3661d83ad1009b1729446d);
#
#
#         var popup_3c6397eacbc568ac5e89252dfbb64c2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd1c1487eadbe9f3622c0419534fb299 = $(`&lt;div id=&quot;html_dd1c1487eadbe9f3622c0419534fb299&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aberdeenshire: 3022 accidents&lt;/div&gt;`)[0];
#                 popup_3c6397eacbc568ac5e89252dfbb64c2e.setContent(html_dd1c1487eadbe9f3622c0419534fb299);
#
#
#
#         marker_2159def539d47a234707497674b21748.bindPopup(popup_3c6397eacbc568ac5e89252dfbb64c2e)
#         ;
#
#
#
#
#             var marker_59e4ceb3505e13091176076f87832912 = L.marker(
#                 [51.045162896367515, -1.7190630844017092],
#                 {}
#             ).addTo(map_f55c1fa3c507a58fbd6798caa5a1931a);
#
#
#             var icon_9f98cccbced01e87d259c2ad01d4074a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_59e4ceb3505e13091176076f87832912.setIcon(icon_9f98cccbced01e87d259c2ad01d4074a);
#
#
#         var popup_4b88054167850268bf3860eabcb6cba2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0381c82689e2e2292145ab08318eb7c7 = $(`&lt;div id=&quot;html_0381c82689e2e2292145ab08318eb7c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adur: 936 accidents&lt;/div&gt;`)[0];
#                 popup_4b88054167850268bf3860eabcb6cba2.setContent(html_0381c82689e2e2292145ab08318eb7c7);
#
#
#
#         marker_59e4ceb3505e13091176076f87832912.bindPopup(popup_4b88054167850268bf3860eabcb6cba2)
#         ;
#
#
#
#
#             var marker_fd47b70b119158fb47e85b387cb19a3f = L.marker(
#                 [54.36469104786036, -3.0238296300675676],
#                 {}
#             ).addTo(map_f55c1fa3c507a58fbd6798caa5a1931
