# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

import datetime

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import datetime

# %%
# first i loaded the dataset
df = pd.read_csv('C:/Users/MSI KATANA/Desktop/DSGP Git Repo/DSGP-GROUP-9/newDataset.csv')
df
# Out:
#         Accident_Index Local_Authority_(District)       Date Day_of_Week  \
# 0        200501BS00001     Kensington and Chelsea   1/4/2005     Tuesday
# 1        200501BS00002     Kensington and Chelsea   1/5/2005   Wednesday
# 2        200501BS00003     Kensington and Chelsea   1/6/2005    Thursday
# 3        200501BS00004     Kensington and Chelsea   1/7/2005      Friday
# 4        200501BS00005     Kensington and Chelsea  1/10/2005      Monday
# ...                ...                        ...        ...         ...
# 1048570  201091NM01760                   Highland  2/18/2010    Thursday
# 1048571  201091NM01881                   Highland  2/21/2010      Sunday
# 1048572  201091NM01935                   Highland  2/23/2010     Tuesday
# 1048573  201091NM01964                   Highland  2/23/2010     Tuesday
# 1048574  201091NM02142                   Highland  2/28/2010      Sunday
#
#           Time  Year     Weather_Conditions Urban / Rural  Speed_limit  \
# ...

# %%
# Checking  missing values in the DataFrame
missing_values_in_data_frame = df.isnull()

# number of missing values in each column
missing_values_count_in_data_frame = df.isnull().sum()

# print the result
print("Missing Values in Each Column:")
print(missing_values_count_in_data_frame)
# Out:
# Missing Values in Each Column:
# Accident_Index                               0
# Local_Authority_(District)                   0
# Date                                         0
# Day_of_Week                                  0
# Time                                       100
# Year                                         0
# Weather_Conditions                           0
# Urban / Rural                                0
# Speed_limit                                  0
# Road_Type                                    0
# Road_Surface                                 0
# Pedestrian_Crossing-Physical_Facilities     37
# Number_of_Vehicles                           0
# Light_Conditions                             0
# Junction_Detail                              0
# Junction_Control                             0
# Accident_Severity                            0
# dtype: int64

# %%
# drop the rows with any missing values
df = df.dropna()
df
# Out:
#         Accident_Index Local_Authority_(District)       Date Day_of_Week  \
# 0        200501BS00001     Kensington and Chelsea   1/4/2005     Tuesday
# 1        200501BS00002     Kensington and Chelsea   1/5/2005   Wednesday
# 2        200501BS00003     Kensington and Chelsea   1/6/2005    Thursday
# 3        200501BS00004     Kensington and Chelsea   1/7/2005      Friday
# 4        200501BS00005     Kensington and Chelsea  1/10/2005      Monday
# ...                ...                        ...        ...         ...
# 1048570  201091NM01760                   Highland  2/18/2010    Thursday
# 1048571  201091NM01881                   Highland  2/21/2010      Sunday
# 1048572  201091NM01935                   Highland  2/23/2010     Tuesday
# 1048573  201091NM01964                   Highland  2/23/2010     Tuesday
# 1048574  201091NM02142                   Highland  2/28/2010      Sunday
#
#           Time  Year     Weather_Conditions Urban / Rural  Speed_limit  \
# ...

# %%
# remove the duplicate values in rows 
df = df.drop_duplicates()
df
# Out:
#         Accident_Index Local_Authority_(District)       Date Day_of_Week  \
# 0        200501BS00001     Kensington and Chelsea   1/4/2005     Tuesday
# 1        200501BS00002     Kensington and Chelsea   1/5/2005   Wednesday
# 2        200501BS00003     Kensington and Chelsea   1/6/2005    Thursday
# 3        200501BS00004     Kensington and Chelsea   1/7/2005      Friday
# 4        200501BS00005     Kensington and Chelsea  1/10/2005      Monday
# ...                ...                        ...        ...         ...
# 1048570  201091NM01760                   Highland  2/18/2010    Thursday
# 1048571  201091NM01881                   Highland  2/21/2010      Sunday
# 1048572  201091NM01935                   Highland  2/23/2010     Tuesday
# 1048573  201091NM01964                   Highland  2/23/2010     Tuesday
# 1048574  201091NM02142                   Highland  2/28/2010      Sunday
#
#           Time  Year     Weather_Conditions Urban / Rural  Speed_limit  \
# ...

# %%
# Checking  missing values in the DataFrame
missing_values_in_data_frame = df.isnull()

# number of missing values in each column
missing_values_count_in_data_frame = df.isnull().sum()

# print the result
print("Missing Values in Each Column:")
print(missing_values_count_in_data_frame)
# Out:
# Missing Values in Each Column:
# Accident_Index                             0
# Local_Authority_(District)                 0
# Date                                       0
# Day_of_Week                                0
# Time                                       0
# Year                                       0
# Weather_Conditions                         0
# Urban / Rural                              0
# Speed_limit                                0
# Road_Type                                  0
# Road_Surface                               0
# Pedestrian_Crossing-Physical_Facilities    0
# Number_of_Vehicles                         0
# Light_Conditions                           0
# Junction_Detail                            0
# Junction_Control                           0
# Accident_Severity                          0
# dtype: int64

# %%
# mainly selected fields
selected_columns = ['Accident_Index', 'Date', 'Day_of_Week', 'Time', 'Local_Authority_(District)', 'Accident_Severity', 'Speed_limit', 'Weather_Conditions', 'Light_Conditions', 'Road_Surface'] 
df_selected = df[selected_columns]
df_selected
# Out:
#         Accident_Index       Date Day_of_Week   Time  \
# 0        200501BS00001   1/4/2005     Tuesday  17:42
# 1        200501BS00002   1/5/2005   Wednesday  17:36
# 2        200501BS00003   1/6/2005    Thursday   0:15
# 3        200501BS00004   1/7/2005      Friday  10:35
# 4        200501BS00005  1/10/2005      Monday  21:13
# ...                ...        ...         ...    ...
# 1048570  201091NM01760  2/18/2010    Thursday   7:00
# 1048571  201091NM01881  2/21/2010      Sunday   3:00
# 1048572  201091NM01935  2/23/2010     Tuesday   9:38
# 1048573  201091NM01964  2/23/2010     Tuesday  18:25
# 1048574  201091NM02142  2/28/2010      Sunday  15:45
#
#         Local_Authority_(District) Accident_Severity  Speed_limit  \
# 0           Kensington and Chelsea           Serious           30
# 1           Kensington and Chelsea            Slight           30
# 2           Kensington and Chelsea            Slight           30
# ...

# %%
import pandas as pd

# Assuming df_selected is your DataFrame
df_selected['Date'] = pd.to_datetime(df_selected['Date'], format='%m/%d/%Y', dayfirst=True)


# Create a new column for time periods (1 to 24)
df_selected['Time_Period'] = pd.to_datetime(df_selected['Time']).dt.hour + 1
df_selected
# Out:
# C:\Users\MSI KATANA\AppData\Local\Temp\ipykernel_16548\3691405665.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Date'] = pd.to_datetime(df_selected['Date'], format='%m/%d/%Y', dayfirst=True)
# C:\Users\MSI KATANA\AppData\Local\Temp\ipykernel_16548\3691405665.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_selected['Time_Period'] = pd.to_datetime(df_selected['Time']).dt.hour + 1
# C:\Users\MSI KATANA\AppData\Local\Temp\ipykernel_16548\3691405665.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Drop the specified columns if they exist
columns_to_drop = ['Day_of_the_Week', 'Time', 'Date']
df_selected = df_selected.drop(columns=columns_to_drop, errors='ignore')
df_selected
# Out:
#         Accident_Index Day_of_Week Local_Authority_(District)  \
# 0        200501BS00001     Tuesday     Kensington and Chelsea
# 1        200501BS00002   Wednesday     Kensington and Chelsea
# 2        200501BS00003    Thursday     Kensington and Chelsea
# 3        200501BS00004      Friday     Kensington and Chelsea
# 4        200501BS00005      Monday     Kensington and Chelsea
# ...                ...         ...                        ...
# 1048570  201091NM01760    Thursday                   Highland
# 1048571  201091NM01881      Sunday                   Highland
# 1048572  201091NM01935     Tuesday                   Highland
# 1048573  201091NM01964     Tuesday                   Highland
# 1048574  201091NM02142      Sunday                   Highland
#
#         Accident_Severity  Speed_limit     Weather_Conditions  \
# 0                 Serious           30  Raining no high winds
# 1                  Slight           30     Fine no high winds
# ...

# %%
df_selected['Accident_Count'] = df_selected.groupby(['Day_of_Week', 'Local_Authority_(District)', 'Accident_Severity', 'Speed_limit', 'Weather_Conditions', 'Light_Conditions', 'Road_Surface', 'Time_Period'])['Accident_Index'].transform('count')
df_selected
# Out:
#         Accident_Index Day_of_Week Local_Authority_(District)  \
# 0        200501BS00001     Tuesday     Kensington and Chelsea
# 1        200501BS00002   Wednesday     Kensington and Chelsea
# 2        200501BS00003    Thursday     Kensington and Chelsea
# 3        200501BS00004      Friday     Kensington and Chelsea
# 4        200501BS00005      Monday     Kensington and Chelsea
# ...                ...         ...                        ...
# 1048570  201091NM01760    Thursday                   Highland
# 1048571  201091NM01881      Sunday                   Highland
# 1048572  201091NM01935     Tuesday                   Highland
# 1048573  201091NM01964     Tuesday                   Highland
# 1048574  201091NM02142      Sunday                   Highland
#
#         Accident_Severity  Speed_limit     Weather_Conditions  \
# 0                 Serious           30  Raining no high winds
# 1                  Slight           30     Fine no high winds
# ...

# %%
# Drop the specified columns if they exist
columns_to_drop2 = ['Accident_Index']
df_selected = df_selected.drop(columns=columns_to_drop2, errors='ignore')
df_selected
# Out:
#         Day_of_Week Local_Authority_(District) Accident_Severity  Speed_limit  \
# 0           Tuesday     Kensington and Chelsea           Serious           30
# 1         Wednesday     Kensington and Chelsea            Slight           30
# 2          Thursday     Kensington and Chelsea            Slight           30
# 3            Friday     Kensington and Chelsea            Slight           30
# 4            Monday     Kensington and Chelsea            Slight           30
# ...             ...                        ...               ...          ...
# 1048570    Thursday                   Highland            Slight           60
# 1048571      Sunday                   Highland            Slight           60
# 1048572     Tuesday                   Highland            Slight           30
# 1048573     Tuesday                   Highland           Serious           60
# 1048574      Sunday                   Highland           Serious           60
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Label Encoding
label_encoder = LabelEncoder()
df_selected['Day_of_Week_labeled'] = label_encoder.fit_transform(df_selected['Day_of_Week'])
df_selected['Local_Authority_(District)_labeled'] = label_encoder.fit_transform(df_selected['Local_Authority_(District)'])
df_selected['Weather_Conditions_labeled'] = label_encoder.fit_transform(df_selected['Weather_Conditions'])
df_selected['Light_Conditions_labeled'] = label_encoder.fit_transform(df_selected['Light_Conditions'])

# %%
df_selected
# Out:
#         Day_of_Week Local_Authority_(District) Accident_Severity  Speed_limit  \
# 0           Tuesday     Kensington and Chelsea           Serious           30
# 1         Wednesday     Kensington and Chelsea            Slight           30
# 2          Thursday     Kensington and Chelsea            Slight           30
# 3            Friday     Kensington and Chelsea            Slight           30
# 4            Monday     Kensington and Chelsea            Slight           30
# ...             ...                        ...               ...          ...
# 1048570    Thursday                   Highland            Slight           60
# 1048571      Sunday                   Highland            Slight           60
# 1048572     Tuesday                   Highland            Slight           30
# 1048573     Tuesday                   Highland           Serious           60
# 1048574      Sunday                   Highland           Serious           60
#
# ...

# %%
# Drop the specified columns if they exist
columns_to_drop3 = ['Day_of_Week', 'Local_Authority_(District)', 'Accident_Severity', 'Speed_limit', 'Weather_Conditions', 'Light_Conditions', 'Road_Surface']
df_selected = df_selected.drop(columns=columns_to_drop3, errors='ignore')
df_selected
# Out:
#          Time_Period  Accident_Count  Day_of_Week_labeled  \
# 0                 18               2                    5
# 1                 18               8                    6
# 2                  1               9                    4
# 3                 11              22                    0
# 4                 22               1                    1
# ...              ...             ...                  ...
# 1048570            8               3                    4
# 1048571            4               1                    3
# 1048572           10               1                    5
# 1048573           19               2                    5
# 1048574           16               1                    3
#
#          Local_Authority_(District)_labeled  Weather_Conditions_labeled  \
# 0                                       182                           6
# 1                                       182                           2
# ...

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1048372 entries, 0 to 1048574
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Time_Period                         1048372 non-null  int32
#  1   Accident_Count                      1048372 non-null  int64
#  2   Day_of_Week_labeled                 1048372 non-null  int32
#  3   Local_Authority_(District)_labeled  1048372 non-null  int32
#  4   Weather_Conditions_labeled          1048372 non-null  int32
#  5   Light_Conditions_labeled            1048372 non-null  int32
# dtypes: int32(5), int64(1)
# memory usage: 36.0 MB

# %%
# Assuming you have a pandas DataFrame 'data' with relevant features and target 'accident_count'

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# Step 1: Split the data
X_train, X_test, y_train, y_test = train_test_split(df_selected.drop('Accident_Count', axis=1), df_selected['Accident_Count'], test_size=0.2, random_state=42)

# Step 2: Choose a model
model = LinearRegression()

# Step 3: Train the model
model.fit(X_train, y_train)

# Step 4: Make predictions
predictions = model.predict(X_test)

# Step 5: Evaluate the model
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 8.547795341758242

# %%
# R-squared (variance) score

r2_variance = r2_score(y_test, predictions)
print(f'R-squared (Variance) Score: {r2_variance}')
# Out:
# R-squared (Variance) Score: 0.0807643695004664

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, classification_report
from scipy.stats import randint
import pandas as pd

# %%
# Step 2: Choose a model (Random Forest)
model = RandomForestRegressor(random_state=42)

# Step 3: Train the model
model.fit(X_train, y_train)

# Step 4: Make predictions
predictions = model.predict(X_test)

# Step 5: Evaluate the model
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 4.0441166383782345

# %%
r2_variance = r2_score(y_test, predictions)
print(f'R-squared (Variance) Score: {r2_variance}')
# Out:
# R-squared (Variance) Score: 0.6923395624987704

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Step 1: Choose a range of values for hyperparameters
param_grid = {
    'n_estimators': [50, 100, 150],  # You can extend the range based on computational resources
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

 #Step 2: Create a Random Forest Regressor model
model = RandomForestRegressor(random_state=42)

 #Step 3: Set up GridSearchCV with the model and parameter grid
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_absolute_error')

# Step 4: Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Step 5: Get the best hyperparameters
best_params = grid_search.best_params_
print(f"Best Hyperparameters: {best_params}")

# Step 6: Evaluate the model with the best hyperparameters
best_model = grid_search.best_estimator_
predictions = best_model.predict(X_test)
mae = mean_absolute_error(y_test, predictions)
(f'Mean Absolute Error with Best Hyperparameters: {mae}')
